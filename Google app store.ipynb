# %% [markdown]
# # Google App Store Analysis
# In this following part we will get to know about the dataset . What type of dataset it is . Does it have any null value or not

# %%
# import all the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter('ignore')

# %%
# Load file
data=pd.read_csv('C:\\Users\\DELL\\Downloads\\Google Apps data.csv')

# %%
# Check the shape of the data(rows*columns)
data.shape
# Out:
# (8276, 15)

# %%
# TO get to know all the information of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8276 entries, 0 to 8275
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0.1         8276 non-null   int64
#  1   Unnamed: 0           8276 non-null   int64
#  2   App                  8276 non-null   object
#  3   Category             8276 non-null   object
#  4   Rating               8276 non-null   float64
#  5   Reviews              8276 non-null   int64
#  6   Size                 8276 non-null   float64
#  7   Installs             8276 non-null   int64
#  8   Type                 8276 non-null   object
#  9   Price                8276 non-null   float64
#  10  Content Rating       7915 non-null   object
#  11  Last Updated         8276 non-null   object
#  12  Current Ver          8276 non-null   object
#  13  Minimum Android Ver  8276 non-null   object
#  14  Genres               8276 non-null   object
# ...

# %%
#Check all the columns name of the dataset
data.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'App', 'Category', 'Rating', 'Reviews',
#        'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Last Updated',
#        'Current Ver', 'Minimum Android Ver', 'Genres'],
#       dtype='object')

# %%
# To find out all the necessary values we used this function
data.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0       Rating       Reviews         Size  \
# count   8276.000000  8276.000000  8276.000000  8.276000e+03  8276.000000
# mean    4137.500000  4560.609957     4.175121  2.803270e+05    18.897761
# std     2389.219747  2560.879748     0.534762  2.096170e+06    22.376521
# min        0.000000     0.000000     1.000000  1.000000e+00     0.008300
# 25%     2068.750000  2459.750000     4.000000  1.290000e+02     2.800000
# 50%     4137.500000  4613.500000     4.300000  3.213500e+03     9.500000
# 75%     6206.250000  6765.250000     4.500000  4.627800e+04    27.000000
# max     8275.000000  8916.000000     5.000000  7.815831e+07   100.000000
#
#            Installs        Price
# count  8.276000e+03  8276.000000
# mean   9.658206e+06     1.028758
# std    5.986505e+07    16.776622
# min    1.000000e+00     0.000000
# 25%    1.000000e+04     0.000000
# 50%    1.000000e+05     0.000000
# 75%    1.000000e+06     0.000000
# max    1.000000e+09   400.000000

# %%
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           5
# 3             3           6
# 4             4           7
#
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  Art And Design     4.1
# 1                                Coloring book moana  Art And Design     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  Art And Design     4.7
# 3                              Sketch - Draw & Paint  Art And Design     4.5
# 4              Pixel Draw - Number Art Coloring Book  Art And Design     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating      Last Updated  \
# 0      159  19.0     10000  Free    0.0         Others   January 7, 2018
# 1      967  14.0    500000  Free    0.0         Others  January 15, 2018
# 2    87510   8.7   5000000  Free    0.0         Others    August 1, 2018
# ...

# %%
data.tail()
# Out:
#       Unnamed: 0.1  Unnamed: 0                                            App  \
# 8271          8271        8912                                  FR Calculator
# 8272          8272        8913                               Sya9a Maroc - FR
# 8273          8273        8914               Fr. Mike Schmitz Audio Teachings
# 8274          8274        8915                  The SCP Foundation DB fr nn5n
# 8275          8275        8916  iHoroscope - 2018 Daily Horoscope & Astrology
#
#                  Category  Rating  Reviews  Size  Installs  Type  Price  \
# 8271               Family     4.0        7   2.6       500  Free    0.0
# 8272               Family     4.5       38  53.0      5000  Free    0.0
# 8273               Family     5.0        4   3.6       100  Free    0.0
# 8274  Books And Reference     4.5      114   1.0      1000  Free    0.0
# 8275            Lifestyle     4.5   398307  19.0  10000000  Free    0.0
#
# ...

# %%
# Check how many null values are present in the dataset
data.isnull().sum()
# Out:
# Unnamed: 0.1             0
# Unnamed: 0               0
# App                      0
# Category                 0
# Rating                   0
# Reviews                  0
# Size                     0
# Installs                 0
# Type                     0
# Price                    0
# Content Rating         361
# Last Updated             0
# Current Ver              0
# Minimum Android Ver      0
# Genres                   0
# dtype: int64

# %%
# Since, the null value is less so we will delete all the rows of that data
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (7915, 15)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0.1           0
# Unnamed: 0             0
# App                    0
# Category               0
# Rating                 0
# Reviews                0
# Size                   0
# Installs               0
# Type                   0
# Price                  0
# Content Rating         0
# Last Updated           0
# Current Ver            0
# Minimum Android Ver    0
# Genres                 0
# dtype: int64

# %%
# These columns has no affect on the data so I deleted such columns.
data.drop('Unnamed: 0.1',axis=1,inplace=True)
data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data1=data.head()
data1
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  Art And Design     4.1
# 1                                Coloring book moana  Art And Design     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  Art And Design     4.7
# 3                              Sketch - Draw & Paint  Art And Design     4.5
# 4              Pixel Draw - Number Art Coloring Book  Art And Design     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating      Last Updated  \
# 0      159  19.0     10000  Free    0.0         Others   January 7, 2018
# 1      967  14.0    500000  Free    0.0         Others  January 15, 2018
# 2    87510   8.7   5000000  Free    0.0         Others    August 1, 2018
# 3   215644  25.0  50000000  Free    0.0           Teen      June 8, 2018
# 4      967   2.8    100000  Free    0.0         Others     June 20, 2018
#
#           Current Ver Minimum Android Ver        Genres
# ...

# %%
data2=data.tail()
data2
# Out:
#                                                 App             Category  \
# 8270                                    Chemin (fr)  Books And Reference
# 8271                                  FR Calculator               Family
# 8272                               Sya9a Maroc - FR               Family
# 8273               Fr. Mike Schmitz Audio Teachings               Family
# 8275  iHoroscope - 2018 Daily Horoscope & Astrology            Lifestyle
#
#       Rating  Reviews      Size  Installs  Type  Price Content Rating  \
# 8270     4.8       44   0.60449      1000  Free    0.0         Others
# 8271     4.0        7   2.60000       500  Free    0.0         Others
# 8272     4.5       38  53.00000      5000  Free    0.0         Others
# 8273     5.0        4   3.60000       100  Free    0.0         Others
# 8275     4.5   398307  19.00000  10000000  Free    0.0         Others
#
#         Last Updated         Current Ver Minimum Android Ver  \
# ...

# %%
# TO join two values together I used concat function to merge them
concat_data=pd.concat([data1,data2],axis=0,ignore_index=True)
concat_data
# Out:
#                                                  App             Category  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook       Art And Design
# 1                                Coloring book moana       Art And Design
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...       Art And Design
# 3                              Sketch - Draw & Paint       Art And Design
# 4              Pixel Draw - Number Art Coloring Book       Art And Design
# 5                                        Chemin (fr)  Books And Reference
# 6                                      FR Calculator               Family
# 7                                   Sya9a Maroc - FR               Family
# 8                   Fr. Mike Schmitz Audio Teachings               Family
# 9      iHoroscope - 2018 Daily Horoscope & Astrology            Lifestyle
#
#    Rating  Reviews      Size  Installs  Type  Price Content Rating  \
# 0     4.1      159  19.00000     10000  Free    0.0         Others
# ...

# %% [markdown]
# # Cleaning Data

# %%
data['Category'].unique()
# Out:
# array(['Art And Design', 'Auto And Vehicles', 'Beauty',
#        'Books And Reference', 'Business', 'Comics', 'Communication',
#        'Dating', 'Education', 'Entertainment', 'Events', 'Finance',
#        'Food And Drink', 'Health And Fitness', 'House And Home',
#        'Libraries And Demo', 'Lifestyle', 'Game', 'Family', 'Medical',
#        'Social', 'Shopping', 'Photography', 'Sports', 'Travel And Local',
#        'Tools', 'Personalization', 'Productivity', 'Parenting', 'Weather',
#        'Video Players', 'News And Magazines', 'Maps And Navigation'],
#       dtype=object)

# %%
data['Rating'].unique()
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 4. , 4.8, 4.9, 3.6,
#        3.7, 3.2, 3.3, 3.4, 3.5, 3.1, 5. , 2.6, 2.8, 3. , 2.5, 2.7, 2.3,
#        2.9, 2.2, 1.7, 2. , 1. , 1.8, 2.4, 1.9, 1.6, 2.1, 1.4, 1.5, 1.2])

# %%
data['Reviews'].unique()
# Out:
# array([   159,    967,  87510, ...,    603,   1195, 398307], dtype=int64)

# %%
data['Size'].unique()
# Out:
# array([1.9000e+01, 1.4000e+01, 8.7000e+00, 2.5000e+01, 2.8000e+00,
#        5.6000e+00, 2.9000e+01, 3.3000e+01, 3.1000e+00, 2.8000e+01,
#        1.2000e+01, 2.0000e+01, 2.1000e+01, 3.7000e+01, 5.5000e+00,
#        1.7000e+01, 3.9000e+01, 3.1000e+01, 4.2000e+00, 2.3000e+01,
#        6.0000e+00, 6.1000e+00, 4.6000e+00, 9.2000e+00, 5.2000e+00,
#        1.1000e+01, 2.4000e+01, 1.0000e+00, 9.4000e+00, 1.5000e+01,
#        1.0000e+01, 1.2000e+00, 2.6000e+01, 8.0000e+00, 7.9000e+00,
#        5.6000e+01, 5.7000e+01, 3.5000e+01, 5.4000e+01, 1.9629e-01,
#        3.6000e+00, 5.7000e+00, 8.6000e+00, 2.4000e+00, 2.7000e+01,
#        2.7000e+00, 2.5000e+00, 7.0000e+00, 1.6000e+01, 3.4000e+00,
#        8.9000e+00, 3.9000e+00, 2.9000e+00, 3.8000e+01, 3.2000e+01,
#        5.4000e+00, 1.8000e+01, 1.1000e+00, 2.2000e+00, 4.5000e+00,
#        9.8000e+00, 5.2000e+01, 9.0000e+00, 6.7000e+00, 3.0000e+01,
#        2.6000e+00, 7.1000e+00, 2.2000e+01, 6.4000e+00, 3.2000e+00,
# ...

# %%
data['Installs'].unique()
# Out:
# array([     10000,     500000,    5000000,   50000000,     100000,
#             50000,    1000000,   10000000,       5000,  100000000,
#        1000000000,       1000,  500000000,        500,        100,
#                10,          5,         50,          1], dtype=int64)

# %%
data['Price'].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   5.99,   3.49,   2.99,   1.99,
#          9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,  24.99,  79.99,
#         11.99,  16.99,  14.99,  29.99,  12.99,   2.49,  10.99,   1.5 ,
#          7.99,  19.99,  15.99,  33.99,  39.99,   3.95,   4.49,   1.7 ,
#          8.99,   1.49,   3.88, 399.99,  17.99, 400.  ,   3.02,   1.76,
#          4.84,   4.77,   1.61,   2.5 ,   1.59,   6.49,   1.29, 299.99,
#        379.99,  37.99,  18.99, 389.99,   8.49,   1.75,  14.  ,   2.  ,
#          3.08,   2.59,  19.4 ,   3.9 ,   4.59,  15.46,   3.04,  13.99,
#          3.28,   4.6 ,   1.  ,   2.95,   2.9 ,   1.97,   2.56,   1.2 ])

# %%
data['Last Updated'].unique()
# Out:
# array(['January 7, 2018', 'January 15, 2018', 'August 1, 2018', ...,
#        'January 20, 2014', 'February 16, 2014', 'March 23, 2014'],
#       dtype=object)

# %%
# I converted the date in the form of object into datetime
data['Last Updated']=pd.to_datetime(data['Last Updated'])
data['Last Updated']
# Out:
# 0      2018-01-07
# 1      2018-01-15
# 2      2018-08-01
# 3      2018-06-08
# 4      2018-06-20
#           ...
# 8270   2014-03-23
# 8271   2017-06-18
# 8272   2017-07-25
# 8273   2018-07-06
# 8275   2018-07-25
# Name: Last Updated, Length: 7915, dtype: datetime64[ns]

# %%
# With the help of corr() function I found the correlation between data
data.corr()
# Out:
#             Rating   Reviews      Size  Installs     Price
# Rating    1.000000  0.059121  0.039942  0.041923 -0.022474
# Reviews   0.059121  1.000000  0.060196  0.608655 -0.008088
# Size      0.039942  0.060196  1.000000 -0.004632 -0.018825
# Installs  0.041923  0.608655 -0.004632  1.000000 -0.009944
# Price    -0.022474 -0.008088 -0.018825 -0.009944  1.000000

# %%
data.describe()
# Out:
#             Rating       Reviews         Size      Installs        Price
# count  7915.000000  7.915000e+03  7915.000000  7.915000e+03  7915.000000
# mean      4.177486  2.821057e+05    18.714311  9.790449e+06     1.063405
# std       0.535871  2.133745e+06    22.239824  6.085541e+07    17.149233
# min       1.000000  1.000000e+00     0.008300  1.000000e+00     0.000000
# 25%       4.000000  1.250000e+02     2.700000  1.000000e+04     0.000000
# 50%       4.300000  3.053000e+03     9.200000  1.000000e+05     0.000000
# 75%       4.500000  4.546750e+04    26.000000  1.000000e+06     0.000000
# max       5.000000  7.815831e+07   100.000000  1.000000e+09   400.000000

# %%
# I have visualized the data in the form pf heatmap to show the correlation between them
plt.figure(figsize=(11,8))
sns.heatmap(data.corr(),annot=True,fmt='.1f')
plt.show()

# %%
category_list=list(data['Category'].unique())
category_review=[]
for i in category_list:
    x=data[data['Category']==i]
    if(len(x)!=0):
        review=sum(x.Reviews)/len(x)
        category_review.append(review)
    else:
        review=sum(x.reviews)
        category_review.append(review)

# %%
#sorting
data_category_reviews = pd.DataFrame({'category': category_list,'review':category_review})
new_index = (data_category_reviews['review'].sort_values(ascending=False)).index.values
sorted_data =data_category_reviews.reindex(new_index)
print(data_category_reviews)
print(sorted_data)
# Out:
#                category        review
# 0        Art And Design  2.365133e+04
# 1     Auto And Vehicles  1.594014e+04
# 2                Beauty  9.625854e+03
# 3   Books And Reference  1.001650e+05
# 4              Business  3.760372e+04
# 5                Comics  4.945874e+04
# 6         Communication  1.122544e+06
# 7                Dating  4.496333e+03
# 8             Education  1.158845e+05
# 9         Entertainment  3.576323e+05
# 10               Events  3.568667e+03
# 11              Finance  4.192644e+04
# 12       Food And Drink  6.728412e+04
# 13   Health And Fitness  8.922464e+04
# 14       House And Home  3.112042e+04
# 15   Libraries And Demo  1.401751e+04
# 16            Lifestyle  2.699894e+04
# 17                 Game  7.006316e+05
# 18               Family  2.100978e+05
# 19              Medical  4.464243e+03
# 20               Social  1.268708e+06
# 21             Shopping  2.486632e+05
# 22          Photography  4.000793e+05
# 23               Sports  2.287879e+05
# ...

# %% [markdown]
# # Category VS Reviews

# %%
plt.figure(figsize=(20,10))
sns.barplot(sorted_data['category'],sorted_data['review'],color='c')
plt.title('Category vs review',fontsize=20,color='green')
plt.xlabel('Category',fontsize=20,color='red')
plt.ylabel('Review',fontsize=20,color='red')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Category VS Installs

# %%
category_list=list(data['Category'].unique())
category_install=[]
for i in category_list:
    x=data[data['Category']==i]
    if(len(x)!=0):
        install=sum(x.Installs)/len(x)
        category_install.append(review)
    else:
        install=sum(x.Installs)
        category_install.append(review)

# %%
#sorting
data_category_install=pd.DataFrame({'category':category_list,'install':category_install})
new_index=(data_category_install['install'].sort_values(ascending=False)).index.values
sorted_data=data_category_install.reindex(new_index)

# %%
plt.figure(figsize=(20,10))
sns.barplot(sorted_data['category'],sorted_data['install'])
plt.title('Category',fontsize=20,color='green')
plt.xlabel('Category',fontsize=20,color='red')
plt.ylabel('Installs',fontsize=20,color='red')
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# # Count plot

# %%
plt.figure(figsize=(10,7))
sns.countplot(data=data,x='Content Rating')
plt.title('Count plot')
plt.xlabel('Count Rating')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Conclusion
# From the above code and the visualization I am able to analyze all the data . I performed EDA parts and make data easy to visualize and analysis
